# %%
import sys
from pathlib import Path

config_file_path = Path.cwd().parent / "config" / "default.json"
sys.argv = ["", "--config", str(config_file_path)]

import nest_asyncio
nest_asyncio.apply()

# %%
from bot.cli.runner import main

main()
# Out:
# 2026-05-30T14:04:20.807349Z [info     ] Starting trading runner        ibkr_host=127.0.0.1 ibkr_port=7497
# 2026-05-30T14:49:30.391949Z [info     ] IBKR connected                 client_id=1 host=172.19.160.1 port=4002
# 2026-05-30T14:49:47.121577Z [info     ] ibkr_execution_provider_ready
# Error 200, reqId 4: No security definition has been found for the request, contract: Future(symbol='ZN', exchange='CME', currency='USD')
# 2026-05-30T14:52:12.832489Z [warning  ] instrument not found during metadata refresh exchange=CME strategy=diagnostic symbol=ZN
# Error 200, reqId 5: No security definition has been found for the request, contract: Future(symbol='ZT', exchange='CME', currency='USD')
# 2026-05-30T14:52:31.918264Z [warning  ] instrument not found during metadata refresh exchange=CME strategy=diagnostic symbol=ZT
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ...
